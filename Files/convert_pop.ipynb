# %%
import pandas as pd

# %%
encodings=['utf-8','latin1','iso-8859-1']
for encoding in encodings:
    try:
        df = pd.read_csv(r"",encoding=encoding)
        print(f'successful')
        break
    except UnicodeDecodeError:
        print(f'failed')
# Out:
# failed
# successful

# %%
df.head()
# Out:
#         Country   1980   1981   1982   1983   1984    1985    1986    1987  \
# 0        Angola  8.272  8.495  8.720  8.948  9.185  10.350  10.646  10.918
# 1         Benin  3.750  3.880  3.999  4.129  4.259   4.400   4.541   4.682
# 2      Botswana  0.963  0.981  1.017  1.055  1.093   1.134   1.176   1.219
# 3  Burkina Faso  7.045  7.212  7.391  7.580  7.776   7.979   8.208   8.435
# 4       Burundi  4.090  4.210  4.334  4.461  4.591   4.726   4.864   5.007
#
#      1988  ...    2015    2016    2017    2018    2019    2020    2021  \
# 0  11.214  ...  28.128  29.155  30.209  31.274  32.354  33.428  34.504
# 1   4.833  ...  10.933  11.260  11.597  11.941  12.290  12.643  12.997
# 2   1.263  ...   2.305   2.352   2.402   2.451   2.500   2.546   2.588
# 3   8.664  ...  18.718  19.275  19.836  20.393  20.952  21.540  22.145
# 4   5.154  ...  10.204  10.530  10.867  11.193  11.529  11.875  12.231
#
#      2022    2023    2024
# 0  35.711  36.783  37.886
# 1  13.366  13.745  14.132
# ...

# %%
df_melted = pd.melt(df, id_vars = ['Country'], var_name = 'Year', value_name = 'Population(M)')

# %%
df_melted.head(50)
# Out:
#                              Country  Year  Population(M)
# 0                             Angola  1980          8.272
# 1                              Benin  1980          3.750
# 2                           Botswana  1980          0.963
# 3                       Burkina Faso  1980          7.045
# 4                            Burundi  1980          4.090
# 5                         Cabo Verde  1980          0.289
# 6                           Cameroon  1980          8.808
# 7           Central African Republic  1980          2.279
# 8                               Chad  1980          4.514
# 9                            Comoros  1980          0.353
# 10  Democratic Republic of the Congo  1980         25.124
# 11                 Republic of Congo  1980          1.707
# 12                     Côte d'Ivoire  1980          7.864
# 13                 Equatorial Guinea  1980          0.255
# 14                           Eritrea  1980          0.000
# ...

# %%
df_melted.to_csv('Population(M).csv',index=False)
